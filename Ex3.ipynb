# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
iris=load_iris()
x=iris.data
y=iris.target
target_names=iris.target_names
Scaler=StandardScaler()
x_scaled=Scaler.fit_transform(x)
pca=PCA(n_components=2)
X_pca=pca.fit_transform(x_scaled)
df_pca=pd.DataFrame(X_pca,columns=['pc1','pc2'])
df_pca['Target']=y
plt.figure(figsize=(8,6))
sns.scatterplot(data=df_pca, x='pc1', y='pc2', hue='Target', palette='viridis', legend='full')
plt.title("PCA projection of Iris Dataset (4D -> 2D)")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")
plt.grid(True)
plt.show()
print("Experiences Varience Ratio",pca.explained_variance_ratio_)
# Out:
# Experiences Varience Ratio [0.72962445 0.22850762]
